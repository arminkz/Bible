# %%
from __future__ import division
import os
import re
import random
import time
import binascii
from bisect import bisect_right
from heapq import heappop, heappush

from os import listdir
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
# Read dataset
sheet = pd.DataFrame()
for csv_file in listdir('./150k/'):
    sheet = sheet.append(pd.read_csv(f'./150k/{csv_file}'))

df = pd.DataFrame(sheet['content'])
# limit data size
df = df[:2000]

# perform some cleaning
df['content'] = df['content'].apply(lambda x: x.replace('\n',''))
df['content'] = df['content'].apply(lambda x: BeautifulSoup(x, features="html.parser").get_text())
df.shape[0]
# Out:
# 2000

# %%
# Calculate Shingles
print("Shingling articles...")

doc_shingle_sets = []

t0 = time.time()
totalShingles = 0

for doc in df['content']:

    # 'shinglesInDoc' will hold all of the unique shingle IDs present in the 
    # current document. If a shingle ID occurs multiple times in the document,
    # it will only appear once in the set (this is a property of Python sets).
    shinglesInDoc = set()
    
    words = doc.split(" ")
    
    # For each word in the document...
    for index in range(0, len(words) - 2):
        # Construct the shingle text by combining three words together.
        shingle = words[index] + " " + words[index + 1] + " " + words[index + 2]

        # Hash the shingle to a 32-bit integer.
        crc = binascii.crc32(shingle.encode('utf-8')) & 0xffffffff
    
        # Add the hash value to the list of shingles for the current document. 
        # Note that set objects will only add the value to the set if the set 
        # doesn't already contain it. 
        shinglesInDoc.add(crc)
    
    # store shingle set
    doc_shingle_sets.append(shinglesInDoc)
    totalShingles = totalShingles + (len(words) - 2)

# Report how long shingling took.
print(f"shingling {df.shape[0]} docs took {time.time() - t0} sec.") 
print(f"average shingles per doc: {totalShingles / df.shape[0]}")
# Out:
# Shingling articles...
# shingling 2000 docs took 1.0387790203094482 sec.
# average shingles per doc: 387.412

# %%
numDocs = df.shape[0]

# %%
# Generate MinHash Signatures
print('Generating random hash functions...')

# Our random hash function will take the form of:
# h(x) = (a*x + b) % c
# Where 'x' is the input value, 'a' and 'b' are random coefficients, and 'c' is
# a prime number just greater than maxShingleID.

# This is the number of components in the resulting MinHash signatures.
# Correspondingly, it is also the number of random hash functions that
# we will need in order to calculate the MinHash.
numHashes = 10;

# Record the maximum shingle ID that we assigned.
maxShingleID = 2**32-1

# We need the next largest prime number above 'maxShingleID'.
nextPrime = 4294967311

def pickRandomCoeffs(k):
    # Create a list of 'k' random values.
    randList = []
    while k > 0:
        # Get a random shingle ID.
        randIndex = random.randint(0, maxShingleID) 
        # Ensure that each random number is unique.
        while randIndex in randList:
            randIndex = random.randint(0, maxShingleID) 
        # Add the random number to the list.
        randList.append(randIndex)
        k = k - 1
    return randList

coeffA = pickRandomCoeffs(numHashes)
coeffB = pickRandomCoeffs(numHashes)
# Out:
# Generating random hash functions...

# %%
print('Generating MinHash signatures for all documents...')

t0 = time.time()

# List of documents represented as signature vectors
signatures = []

for i in range(numDocs):
    
    # Get the shingle set for this document.
    shingle_set = doc_shingle_sets[i]
    
    # The resulting minhash signature for this document. 
    signature = []
    
    for i in range(0, numHashes):
        minHashCode = nextPrime + 1
        
        for shingle in shingle_set:
            # Evaluate the hash function.
            hashCode = (coeffA[i] * shingle + coeffB[i]) % nextPrime
            
            # Track the lowest hash code seen.
            if hashCode < minHashCode:
                minHashCode = hashCode
        
        # store doc signature
        signature.append(minHashCode)
        
    # Store the MinHash signature for this document.
    signatures.append(signature)
    
print(f"Generating MinHash signatures took {time.time() - t0} sec")
# Out:
# Generating MinHash signatures for all documents...
# Generating MinHash signatures took 2.880990982055664 sec

# %%
# Compare All Signatures
print('Comparing all signatures...')

similar_docs = []

jac_threshold = 0.5

t0 = time.time()

for i in range(numDocs):
    
    similar_to_i = []
    
    # Get the MinHash signature for document i.
    signature1 = signatures[i]
    
    for j in range(i + 1, numDocs):
    
        # Get the MinHash signature for document j.
        signature2 = signatures[j]
    
        count = 0
        # Count the number of positions in the minhash signature which are equal.
        for k in range(0, numHashes):
            count = count + (signature1[k] == signature2[k])
    
        # Record the percentage of positions which matched.
        estJSim = (count / numHashes)
    
        if estJSim > jac_threshold:
            similar_to_i.append(j)
    
    similar_docs.append(similar_to_i)
        
print(f"Comparing MinHash signatures took {time.time() - t0} sec")
# Out:
# Comparing all signatures...
# Comparing MinHash signatures took 4.73025107383728 sec

# %%
# Aggregate Data
# final = pd.DataFrame(columns=['content','similar_docs'])
for i in range(numDocs):
    sim_to_i = similar_docs[i]
    res = ''
    for j in sim_to_i:
        res += str(j) + ","
    print(f"similars to {i} : {res}")
# Out:
# similars to 0 :
# similars to 1 :
# similars to 2 :
# similars to 3 :
# similars to 4 :
# similars to 5 :
# similars to 6 :
# similars to 7 :
# similars to 8 : 26,105,115,766,999,1719,1888,1974,
# similars to 9 :
# similars to 10 : 1006,1023,1475,
# similars to 11 :
# similars to 12 :
# similars to 13 :
# similars to 14 :
# similars to 15 :
# similars to 16 :
# similars to 17 :
# similars to 18 :
# similars to 19 :
# similars to 20 :
# similars to 21 :
# similars to 22 :
# similars to 23 :
# similars to 24 :
# similars to 25 :
# similars to 26 : 105,115,766,999,1719,1888,1974,
# similars to 27 :
# similars to 28 :
# similars to 29 :
# similars to 30 :
# similars to 31 :
# similars to 32 :
# similars to 33 : 1960,
# similars to 34 : 934,
# similars to 35 :
# similars to 36 :
# similars to 37 :
# similars to 38 :
# similars to 39 :
# similars to 40 :
# similars to 41 :
# similars to 42 :
# similars to 43 :
# similars to 44 :
# similars to 45 : 275,1347,
# similars to 46 :
# similars to 47 :
# similars to 48 :
# similars to 49 :
# similars to 50 :
# similars to 51 :
# similars to 52 :
# similars to 53 : 1929,
# similars to 54 :
# similars to 55 :
# similars to 56 :
# similars to 57 :
# similars to 58 :
# similars to 59 :
# similars to 60 :
# similars to 61 :
# similars to 62 :
# similars to 63 :
# similars to 64 :
# similars to 65 :
# similars to 66 :
# similars to 67 :
# similars to 68 :
# similars to 69 :
# similars to 70 :
# similars to 71 :
# similars to 72 :
# similars to 73 :
# similars to 74 : 103,
# similars to 75 :
# similars to 76 :
# similars to 77 :
# similars to 78 :
# similars to 79 :
# similars to 80 :
# similars to 81 :
# similars to 82 :
# similars to 83 : 1762,
# similars to 84 :
# similars to 85 :
# similars to 86 :
# similars to 87 :
# similars to 88 :
# similars to 89 :
# similars to 90 :
# similars to 91 :
# similars to 92 :
# similars to 93 :
# similars to 94 :
# similars to 95 :
# similars to 96 :
# similars to 97 :
# similars to 98 :
# similars to 99 :
# similars to 100 :
# similars to 101 :
# similars to 102 :
# similars to 103 : 1558,1796,
# similars to 104 :
# similars to 105 : 115,766,999,1719,1888,1974,
# similars to 106 :
# similars to 107 :
# similars to 108 :
# similars to 109 :
# similars to 110 :
# similars to 111 :
# similars to 112 :
# similars to 113 :
# similars to 114 :
# similars to 115 : 766,999,1719,1888,1974,
# similars to 116 :
# similars to 117 :
# similars to 118 :
# similars to 119 : 1675,
# similars to 120 :
# similars to 121 : 779,895,908,1802,1876,
# similars to 122 : 141,187,228,521,592,609,767,779,895,908,1006,1039,1065,1067,1154,1195,1221,1346,1368,1387,1449,1452,1467,1475,1633,1671,1732,1802,1828,1876,1995,
# similars to 123 :
# similars to 124 :
# similars to 125 :
# similars to 126 :
# similars to 127 :
# similars to 128 :
# similars to 129 :
# similars to 130 :
# similars to 131 :
# similars to 132 :
# similars to 133 :
# similars to 134 :
# similars to 135 :
# similars to 136 :
# similars to 137 :
# similars to 138 :
# similars to 139 :
# similars to 140 :
# similars to 141 : 187,228,521,592,609,767,895,908,1006,1039,1065,1067,1154,1195,1221,1346,1368,1387,1449,1452,1467,1475,1633,1671,1732,1802,1828,1876,1995,
# similars to 142 :
# similars to 143 :
# similars to 144 :
# similars to 145 :
# similars to 146 :
# similars to 147 :
# similars to 148 :
# similars to 149 : 1725,1922,1989,
# similars to 150 :
# similars to 151 :
# similars to 152 : 163,
# similars to 153 : 1541,
# similars to 154 :
# similars to 155 :
# similars to 156 :
# similars to 157 :
# similars to 158 :
# similars to 159 :
# similars to 160 :
# similars to 161 :
# similars to 162 :
# similars to 163 :
# similars to 164 :
# similars to 165 : 1901,
# similars to 166 :
# similars to 167 :
# similars to 168 : 1488,
# similars to 169 :
# similars to 170 :
# similars to 171 :
# similars to 172 :
# similars to 173 :
# similars to 174 : 413,
# similars to 175 :
# similars to 176 :
# similars to 177 :
# similars to 178 :
# similars to 179 :
# similars to 180 :
# similars to 181 :
# similars to 182 : 592,779,895,908,1802,
# similars to 183 :
# similars to 184 :
# similars to 185 :
# similars to 186 :
# similars to 187 : 228,521,767,1006,1067,1221,1387,1671,1732,1828,
# similars to 188 :
# similars to 189 :
# similars to 190 :
# similars to 191 :
# similars to 192 :
# similars to 193 :
# similars to 194 :
# similars to 195 :
# similars to 196 :
# similars to 197 :
# similars to 198 :
# similars to 199 :
# similars to 200 :
# similars to 201 :
# similars to 202 :
# similars to 203 :
# similars to 204 :
# similars to 205 :
# similars to 206 :
# similars to 207 : 1560,
# similars to 208 :
# similars to 209 :
# similars to 210 :
# similars to 211 :
# similars to 212 :
# similars to 213 :
# similars to 214 :
# similars to 215 :
# similars to 216 :
# similars to 217 :
# similars to 218 :
# similars to 219 :
# similars to 220 :
# similars to 221 :
# similars to 222 :
# similars to 223 :
# similars to 224 :
# similars to 225 :
# similars to 226 :
# similars to 227 :
# similars to 228 : 521,592,767,1006,1067,1221,1387,1467,1643,1671,1732,1828,
# similars to 229 : 386,1196,
# similars to 230 :
# similars to 231 :
# similars to 232 :
# similars to 233 :
# similars to 234 :
# similars to 235 :
# similars to 236 :
# similars to 237 : 1258,
# similars to 238 :
# similars to 239 :
# similars to 240 :
# similars to 241 :
# similars to 242 :
# similars to 243 :
# similars to 244 :
# similars to 245 :
# similars to 246 :
# similars to 247 :
# similars to 248 :
# similars to 249 : 1070,
# similars to 250 :
# similars to 251 :
# similars to 252 :
# similars to 253 :
# similars to 254 :
# similars to 255 :
# similars to 256 :
# similars to 257 :
# similars to 258 :
# similars to 259 :
# similars to 260 :
# similars to 261 :
# similars to 262 :
# similars to 263 :
# similars to 264 :
# similars to 265 :
# similars to 266 :
# similars to 267 :
# similars to 268 :
# similars to 269 :
# similars to 270 :
# similars to 271 :
# similars to 272 :
# similars to 273 :
# similars to 274 :
# similars to 275 : 1347,
# similars to 276 :
# similars to 277 :
# similars to 278 :
# similars to 279 :
# similars to 280 :
# similars to 281 :
# similars to 282 :
# similars to 283 :
# similars to 284 :
# similars to 285 :
# similars to 286 :
# similars to 287 :
# similars to 288 :
# similars to 289 :
# similars to 290 : 1899,
# similars to 291 : 779,
# similars to 292 :
# similars to 293 :
# similars to 294 :
# similars to 295 :
# similars to 296 :
# similars to 297 :
# similars to 298 :
# similars to 299 :
# similars to 300 :
# similars to 301 :
# similars to 302 :
# similars to 303 :
# similars to 304 :
# similars to 305 :
# similars to 306 :
# similars to 307 :
# similars to 308 :
# similars to 309 :
# similars to 310 :
# similars to 311 :
# similars to 312 :
# similars to 313 :
# similars to 314 :
# similars to 315 :
# similars to 316 :
# similars to 317 :
# similars to 318 :
# similars to 319 :
# similars to 320 :
# similars to 321 :
# similars to 322 :
# similars to 323 :
# similars to 324 :
# similars to 325 :
# similars to 326 :
# similars to 327 : 825,
# similars to 328 :
# similars to 329 :
# similars to 330 :
# similars to 331 :
# similars to 332 :
# similars to 333 :
# similars to 334 :
# similars to 335 :
# similars to 336 :
# similars to 337 :
# similars to 338 :
# similars to 339 :
# similars to 340 :
# similars to 341 :
# similars to 342 :
# similars to 343 :
# similars to 344 :
# similars to 345 :
# similars to 346 :
# similars to 347 :
# similars to 348 :
# similars to 349 :
# similars to 350 :
# similars to 351 :
# similars to 352 :
# similars to 353 : 754,
# similars to 354 :
# similars to 355 :
# similars to 356 :
# similars to 357 :
# similars to 358 :
# similars to 359 : 1049,
# similars to 360 :
# similars to 361 :
# similars to 362 : 1583,
# similars to 363 :
# similars to 364 :
# similars to 365 :
# similars to 366 :
# similars to 367 :
# similars to 368 :
# similars to 369 :
# similars to 370 :
# similars to 371 :
# similars to 372 :
# similars to 373 :
# similars to 374 :
# similars to 375 :
# similars to 376 :
# similars to 377 :
# similars to 378 :
# similars to 379 :
# similars to 380 :
# similars to 381 :
# similars to 382 :
# similars to 383 :
# similars to 384 :
# similars to 385 :
# similars to 386 : 1196,
# similars to 387 :
# similars to 388 :
# similars to 389 :
# similars to 390 :
# similars to 391 :
# similars to 392 :
# similars to 393 :
# similars to 394 : 496,
# similars to 395 :
# similars to 396 :
# similars to 397 :
# similars to 398 :
# similars to 399 :
# similars to 400 :
# similars to 401 :
# similars to 402 :
# similars to 403 :
# similars to 404 :
# similars to 405 : 440,
# similars to 406 :
# similars to 407 :
# similars to 408 :
# similars to 409 :
# similars to 410 :
# similars to 411 : 1091,
# similars to 412 :
# similars to 413 :
# similars to 414 :
# similars to 415 :
# similars to 416 :
# similars to 417 :
# similars to 418 :
# similars to 419 :
# similars to 420 :
# similars to 421 :
# similars to 422 :
# similars to 423 :
# similars to 424 :
# similars to 425 :
# similars to 426 :
# similars to 427 :
# similars to 428 :
# similars to 429 :
# similars to 430 :
# similars to 431 :
# similars to 432 :
# similars to 433 :
# similars to 434 :
# similars to 435 :
# similars to 436 :
# similars to 437 :
# similars to 438 :
# similars to 439 :
# similars to 440 :
# similars to 441 :
# similars to 442 :
# similars to 443 :
# similars to 444 :
# similars to 445 :
# similars to 446 :
# similars to 447 :
# similars to 448 :
# similars to 449 :
# similars to 450 :
# similars to 451 : 587,
# similars to 452 :
# similars to 453 : 640,
# similars to 454 :
# similars to 455 :
# similars to 456 :
# similars to 457 :
# similars to 458 :
# similars to 459 :
# similars to 460 :
# similars to 461 :
# similars to 462 :
# similars to 463 :
# similars to 464 :
# similars to 465 :
# similars to 466 :
# similars to 467 :
# similars to 468 :
# similars to 469 : 1041,1058,
# similars to 470 :
# similars to 471 :
# similars to 472 :
# similars to 473 :
# similars to 474 :
# similars to 475 :
# similars to 476 :
# similars to 477 :
# similars to 478 :
# similars to 479 :
# similars to 480 :
# similars to 481 : 1484,
# similars to 482 :
# similars to 483 :
# similars to 484 :
# similars to 485 :
# similars to 486 :
# similars to 487 :
# similars to 488 : 1059,
# similars to 489 :
# similars to 490 :
# similars to 491 :
# similars to 492 :
# similars to 493 : 925,
# similars to 494 :
# similars to 495 :
# similars to 496 :
# similars to 497 :
# similars to 498 :
# similars to 499 : 889,
# similars to 500 :
# similars to 501 :
# similars to 502 :
# similars to 503 :
# similars to 504 :
# similars to 505 :
# similars to 506 :
# similars to 507 :
# similars to 508 :
# similars to 509 :
# similars to 510 :
# similars to 511 :
# similars to 512 :
# similars to 513 :
# similars to 514 :
# similars to 515 :
# similars to 516 :
# similars to 517 :
# similars to 518 :
# similars to 519 :
# similars to 520 :
# similars to 521 : 592,609,767,779,895,908,1006,1039,1065,1067,1154,1195,1221,1346,1368,1387,1449,1452,1467,1475,1633,1671,1732,1802,1828,1876,1995,
# similars to 522 :
# similars to 523 :
# similars to 524 :
# similars to 525 :
# similars to 526 :
# similars to 527 :
# similars to 528 :
# similars to 529 :
# similars to 530 :
# similars to 531 :
# similars to 532 :
# similars to 533 :
# similars to 534 :
# similars to 535 :
# similars to 536 :
# similars to 537 :
# similars to 538 :
# similars to 539 :
# similars to 540 :
# similars to 541 :
# similars to 542 :
# similars to 543 :
# similars to 544 :
# similars to 545 :
# similars to 546 :
# similars to 547 :
# similars to 548 :
# similars to 549 :
# similars to 550 :
# similars to 551 :
# similars to 552 :
# similars to 553 :
# similars to 554 :
# similars to 555 : 1561,
# similars to 556 :
# similars to 557 :
# similars to 558 : 1583,
# similars to 559 :
# similars to 560 :
# similars to 561 : 702,1103,
# similars to 562 :
# similars to 563 :
# similars to 564 :
# similars to 565 :
# similars to 566 :
# similars to 567 :
# similars to 568 :
# similars to 569 :
# similars to 570 :
# similars to 571 :
# similars to 572 :
# similars to 573 :
# similars to 574 :
# similars to 575 :
# similars to 576 :
# similars to 577 :
# similars to 578 :
# similars to 579 :
# similars to 580 :
# similars to 581 :
# similars to 582 :
# similars to 583 : 1444,1492,
# similars to 584 :
# similars to 585 :
# similars to 586 :
# similars to 587 :
# similars to 588 :
# similars to 589 :
# similars to 590 :
# similars to 591 :
# similars to 592 : 779,895,908,1006,1346,1467,1802,1876,
# similars to 593 :
# similars to 594 :
# similars to 595 :
# similars to 596 :
# similars to 597 :
# similars to 598 :
# similars to 599 :
# similars to 600 :
# similars to 601 :
# similars to 602 :
# similars to 603 :
# similars to 604 :
# similars to 605 :
# similars to 606 :
# similars to 607 :
# similars to 608 :
# similars to 609 : 767,895,908,1006,1039,1065,1067,1154,1221,1346,1368,1387,1449,1452,1475,1633,1671,1802,1828,1876,1995,
# similars to 610 :
# similars to 611 :
# similars to 612 :
# similars to 613 :
# similars to 614 :
# similars to 615 :
# similars to 616 :
# similars to 617 :
# similars to 618 :
# similars to 619 :
# similars to 620 :
# similars to 621 :
# similars to 622 :
# similars to 623 :
# similars to 624 :
# similars to 625 :
# similars to 626 :
# similars to 627 :
# similars to 628 :
# similars to 629 :
# similars to 630 :
# similars to 631 :
# similars to 632 :
# similars to 633 :
# similars to 634 :
# similars to 635 :
# similars to 636 :
# similars to 637 :
# similars to 638 :
# similars to 639 :
# similars to 640 :
# similars to 641 :
# similars to 642 :
# similars to 643 :
# similars to 644 :
# similars to 645 :
# similars to 646 :
# similars to 647 :
# similars to 648 :
# similars to 649 :
# similars to 650 : 1350,
# similars to 651 :
# similars to 652 :
# similars to 653 :
# similars to 654 :
# similars to 655 :
# similars to 656 :
# similars to 657 :
# similars to 658 :
# similars to 659 :
# similars to 660 :
# similars to 661 :
# similars to 662 :
# similars to 663 :
# similars to 664 :
# similars to 665 :
# similars to 666 :
# similars to 667 :
# similars to 668 :
# similars to 669 :
# similars to 670 :
# similars to 671 :
# similars to 672 :
# similars to 673 :
# similars to 674 :
# similars to 675 :
# similars to 676 :
# similars to 677 :
# similars to 678 :
# similars to 679 :
# similars to 680 :
# similars to 681 :
# similars to 682 :
# similars to 683 :
# similars to 684 :
# similars to 685 :
# similars to 686 :
# similars to 687 :
# similars to 688 :
# similars to 689 :
# similars to 690 :
# similars to 691 :
# similars to 692 :
# similars to 693 :
# similars to 694 :
# similars to 695 :
# similars to 696 :
# similars to 697 :
# similars to 698 :
# similars to 699 :
# similars to 700 :
# similars to 701 :
# similars to 702 : 1103,
# similars to 703 :
# similars to 704 : 1492,
# similars to 705 :
# similars to 706 :
# similars to 707 :
# similars to 708 :
# similars to 709 :
# similars to 710 :
# similars to 711 :
# similars to 712 :
# similars to 713 :
# similars to 714 :
# similars to 715 :
# similars to 716 :
# similars to 717 :
# similars to 718 :
# similars to 719 :
# similars to 720 :
# similars to 721 :
# similars to 722 :
# similars to 723 :
# similars to 724 :
# similars to 725 : 1777,
# similars to 726 :
# similars to 727 :
# similars to 728 :
# similars to 729 :
# similars to 730 :
# similars to 731 :
# similars to 732 :
# similars to 733 :
# similars to 734 :
# similars to 735 :
# similars to 736 :
# similars to 737 : 1674,
# similars to 738 :
# similars to 739 : 1330,
# similars to 740 : 1473,
# similars to 741 :
# similars to 742 :
# similars to 743 :
# similars to 744 :
# similars to 745 :
# similars to 746 :
# similars to 747 :
# similars to 748 :
# similars to 749 :
# similars to 750 :
# similars to 751 :
# similars to 752 : 777,
# similars to 753 :
# similars to 754 :
# similars to 755 :
# similars to 756 :
# similars to 757 :
# similars to 758 :
# similars to 759 :
# similars to 760 :
# similars to 761 :
# similars to 762 :
# similars to 763 :
# similars to 764 :
# similars to 765 :
# similars to 766 : 999,1719,1888,1974,
# similars to 767 : 779,895,908,1006,1039,1065,1067,1154,1195,1221,1346,1387,1449,1452,1475,1633,1671,1732,1802,1828,1876,1995,
# similars to 768 :
# similars to 769 :
# similars to 770 :
# similars to 771 :
# similars to 772 : 895,908,
# similars to 773 :
# similars to 774 :
# similars to 775 :
# similars to 776 :
# similars to 777 :
# similars to 778 :
# similars to 779 : 895,908,1006,1067,1221,1387,1802,1828,1868,1876,
# similars to 780 : 1605,
# similars to 781 :
# similars to 782 :
# similars to 783 :
# similars to 784 :
# similars to 785 :
# similars to 786 :
# similars to 787 :
# similars to 788 :
# similars to 789 :
# similars to 790 :
# similars to 791 :
# similars to 792 :
# similars to 793 :
# similars to 794 : 1780,
# similars to 795 :
# similars to 796 :
# similars to 797 :
# similars to 798 :
# similars to 799 :
# similars to 800 :
# similars to 801 : 1558,1796,
# similars to 802 :
# similars to 803 :
# similars to 804 :
# similars to 805 :
# similars to 806 :
# similars to 807 :
# similars to 808 :
# similars to 809 :
# similars to 810 :
# similars to 811 :
# similars to 812 :
# similars to 813 :
# similars to 814 :
# similars to 815 :
# similars to 816 :
# similars to 817 :
# similars to 818 :
# similars to 819 :
# similars to 820 :
# similars to 821 :
# similars to 822 :
# similars to 823 :
# similars to 824 :
# similars to 825 :
# similars to 826 : 1715,
# similars to 827 : 1549,
# similars to 828 :
# similars to 829 :
# similars to 830 :
# similars to 831 :
# similars to 832 : 1341,
# similars to 833 :
# similars to 834 :
# similars to 835 :
# similars to 836 :
# similars to 837 : 1464,
# similars to 838 : 1240,
# similars to 839 :
# similars to 840 :
# similars to 841 :
# similars to 842 :
# similars to 843 :
# similars to 844 :
# similars to 845 :
# similars to 846 :
# similars to 847 :
# similars to 848 :
# similars to 849 :
# similars to 850 :
# similars to 851 :
# similars to 852 :
# similars to 853 :
# similars to 854 :
# similars to 855 :
# similars to 856 :
# similars to 857 :
# similars to 858 :
# similars to 859 :
# similars to 860 :
# similars to 861 :
# similars to 862 :
# similars to 863 :
# similars to 864 :
# similars to 865 :
# similars to 866 :
# similars to 867 :
# similars to 868 :
# similars to 869 :
# similars to 870 :
# similars to 871 :
# similars to 872 :
# similars to 873 :
# similars to 874 : 1041,
# similars to 875 :
# similars to 876 :
# similars to 877 :
# similars to 878 :
# similars to 879 :
# similars to 880 :
# similars to 881 :
# similars to 882 :
# similars to 883 :
# similars to 884 :
# similars to 885 :
# similars to 886 :
# similars to 887 :
# similars to 888 :
# similars to 889 :
# similars to 890 :
# similars to 891 :
# similars to 892 :
# similars to 893 :
# similars to 894 :
# similars to 895 : 908,1006,1039,1065,1067,1154,1195,1221,1346,1387,1449,1452,1475,1633,1671,1802,1828,1868,1876,1995,
# similars to 896 :
# similars to 897 :
# similars to 898 :
# similars to 899 :
# similars to 900 :
# similars to 901 :
# similars to 902 :
# similars to 903 :
# similars to 904 :
# similars to 905 :
# similars to 906 :
# similars to 907 :
# similars to 908 : 1006,1039,1065,1067,1154,1195,1221,1346,1368,1387,1449,1452,1475,1633,1671,1802,1828,1868,1876,1995,
# similars to 909 :
# similars to 910 :
# similars to 911 :
# similars to 912 :
# similars to 913 :
# similars to 914 :
# similars to 915 :
# similars to 916 :
# similars to 917 :
# similars to 918 :
# similars to 919 :
# similars to 920 :
# similars to 921 :
# similars to 922 :
# similars to 923 :
# similars to 924 :
# similars to 925 :
# similars to 926 :
# similars to 927 :
# similars to 928 :
# similars to 929 :
# similars to 930 :
# similars to 931 :
# similars to 932 :
# similars to 933 :
# similars to 934 :
# similars to 935 :
# similars to 936 :
# similars to 937 :
# similars to 938 :
# similars to 939 :
# similars to 940 :
# similars to 941 :
# similars to 942 : 1429,
# similars to 943 :
# similars to 944 :
# similars to 945 :
# similars to 946 :
# similars to 947 :
# similars to 948 :
# similars to 949 :
# similars to 950 :
# similars to 951 :
# similars to 952 :
# similars to 953 :
# similars to 954 :
# similars to 955 :
# similars to 956 :
# similars to 957 :
# similars to 958 :
# similars to 959 :
# similars to 960 :
# similars to 961 :
# similars to 962 :
# similars to 963 :
# similars to 964 :
# similars to 965 :
# similars to 966 :
# similars to 967 :
# similars to 968 :
# similars to 969 :
# similars to 970 :
# similars to 971 :
# similars to 972 :
# similars to 973 :
# similars to 974 :
# similars to 975 :
# similars to 976 :
# similars to 977 :
# similars to 978 :
# similars to 979 :
# similars to 980 :
# similars to 981 :
# similars to 982 :
# similars to 983 :
# similars to 984 :
# similars to 985 :
# similars to 986 :
# similars to 987 :
# similars to 988 :
# similars to 989 :
# similars to 990 :
# similars to 991 :
# similars to 992 :
# similars to 993 :
# similars to 994 :
# similars to 995 :
# similars to 996 :
# similars to 997 :
# similars to 998 :
# similars to 999 : 1719,1888,1974,
# similars to 1000 :
# similars to 1001 :
# similars to 1002 :
# similars to 1003 :
# similars to 1004 :
# similars to 1005 :
# similars to 1006 : 1023,1039,1065,1067,1154,1195,1221,1346,1368,1387,1449,1452,1467,1475,1633,1671,1732,1802,1828,1876,1995,
# similars to 1007 :
# similars to 1008 :
# similars to 1009 : 1097,
# similars to 1010 :
# similars to 1011 :
# similars to 1012 :
# similars to 1013 :
# similars to 1014 :
# similars to 1015 :
# similars to 1016 :
# similars to 1017 :
# similars to 1018 :
# similars to 1019 :
# similars to 1020 :
# similars to 1021 :
# similars to 1022 :
# similars to 1023 : 1475,
# similars to 1024 :
# similars to 1025 :
# similars to 1026 :
# similars to 1027 :
# similars to 1028 :
# similars to 1029 :
# similars to 1030 :
# similars to 1031 :
# similars to 1032 :
# similars to 1033 :
# similars to 1034 :
# similars to 1035 :
# similars to 1036 :
# similars to 1037 :
# similars to 1038 :
# similars to 1039 : 1065,1067,1154,1221,1346,1368,1387,1449,1452,1467,1475,1633,1671,1802,1828,1876,1995,
# similars to 1040 :
# similars to 1041 : 1058,
# similars to 1042 :
# similars to 1043 :
# similars to 1044 :
# similars to 1045 :
# similars to 1046 :
# similars to 1047 :
# similars to 1048 :
# similars to 1049 :
# similars to 1050 :
# similars to 1051 :
# similars to 1052 : 1160,
# similars to 1053 :
# similars to 1054 :
# similars to 1055 :
# similars to 1056 :
# similars to 1057 :
# similars to 1058 :
# similars to 1059 :
# similars to 1060 : 1566,
# similars to 1061 :
# similars to 1062 :
# similars to 1063 :
# similars to 1064 :
# similars to 1065 : 1067,1154,1221,1368,1387,1452,1475,1633,1671,1802,1828,1995,
# similars to 1066 :
# similars to 1067 : 1154,1221,1387,1452,1475,1633,1671,1732,1802,1828,1995,
# similars to 1068 :
# similars to 1069 :
# similars to 1070 :
# similars to 1071 :
# similars to 1072 :
# similars to 1073 :
# similars to 1074 :
# similars to 1075 :
# similars to 1076 :
# similars to 1077 :
# similars to 1078 :
# similars to 1079 :
# similars to 1080 :
# similars to 1081 :
# similars to 1082 :
# similars to 1083 :
# similars to 1084 :
# similars to 1085 :
# similars to 1086 :
# similars to 1087 :
# similars to 1088 :
# similars to 1089 :
# similars to 1090 :
# similars to 1091 :
# similars to 1092 :
# similars to 1093 :
# similars to 1094 :
# similars to 1095 :
# similars to 1096 :
# similars to 1097 :
# similars to 1098 :
# similars to 1099 :
# similars to 1100 :
# similars to 1101 :
# similars to 1102 :
# similars to 1103 :
# similars to 1104 :
# similars to 1105 :
# similars to 1106 :
# similars to 1107 :
# similars to 1108 :
# similars to 1109 :
# similars to 1110 :
# similars to 1111 :
# similars to 1112 :
# similars to 1113 :
# similars to 1114 :
# similars to 1115 :
# similars to 1116 :
# similars to 1117 :
# similars to 1118 :
# similars to 1119 :
# similars to 1120 : 1153,
# similars to 1121 :
# similars to 1122 :
# similars to 1123 :
# similars to 1124 :
# similars to 1125 :
# similars to 1126 :
# similars to 1127 :
# similars to 1128 :
# similars to 1129 :
# similars to 1130 :
# similars to 1131 :
# similars to 1132 :
# similars to 1133 :
# similars to 1134 :
# similars to 1135 :
# similars to 1136 :
# similars to 1137 :
# similars to 1138 :
# similars to 1139 :
# similars to 1140 :
# similars to 1141 :
# similars to 1142 :
# similars to 1143 : 1170,
# similars to 1144 :
# similars to 1145 :
# similars to 1146 :
# similars to 1147 :
# similars to 1148 :
# similars to 1149 :
# similars to 1150 :
# similars to 1151 :
# similars to 1152 :
# similars to 1153 :
# similars to 1154 : 1221,1368,1387,1452,1467,1475,1633,1671,1802,1828,1995,
# similars to 1155 :
# similars to 1156 :
# similars to 1157 :
# similars to 1158 :
# similars to 1159 :
# similars to 1160 :
# similars to 1161 :
# similars to 1162 :
# similars to 1163 :
# similars to 1164 :
# similars to 1165 :
# similars to 1166 :
# similars to 1167 :
# similars to 1168 :
# similars to 1169 :
# similars to 1170 :
# similars to 1171 :
# similars to 1172 :
# similars to 1173 :
# similars to 1174 :
# similars to 1175 :
# similars to 1176 :
# similars to 1177 :
# similars to 1178 :
# similars to 1179 :
# similars to 1180 :
# similars to 1181 :
# similars to 1182 :
# similars to 1183 :
# similars to 1184 :
# similars to 1185 :
# similars to 1186 :
# similars to 1187 :
# similars to 1188 :
# similars to 1189 :
# similars to 1190 :
# similars to 1191 :
# similars to 1192 :
# similars to 1193 :
# similars to 1194 :
# similars to 1195 : 1346,1387,1671,1802,1828,
# similars to 1196 :
# similars to 1197 :
# similars to 1198 :
# similars to 1199 :
# similars to 1200 :
# similars to 1201 :
# similars to 1202 :
# similars to 1203 :
# similars to 1204 :
# similars to 1205 :
# similars to 1206 :
# similars to 1207 :
# similars to 1208 :
# similars to 1209 :
# similars to 1210 :
# similars to 1211 :
# similars to 1212 :
# similars to 1213 :
# similars to 1214 :
# similars to 1215 :
# similars to 1216 :
# similars to 1217 :
# similars to 1218 :
# similars to 1219 :
# similars to 1220 :
# similars to 1221 : 1387,1452,1475,1633,1671,1732,1802,1828,
# similars to 1222 :
# similars to 1223 :
# similars to 1224 :
# similars to 1225 :
# similars to 1226 :
# similars to 1227 :
# similars to 1228 :
# similars to 1229 :
# similars to 1230 :
# similars to 1231 :
# similars to 1232 :
# similars to 1233 :
# similars to 1234 :
# similars to 1235 :
# similars to 1236 :
# similars to 1237 :
# similars to 1238 :
# similars to 1239 :
# similars to 1240 :
# similars to 1241 :
# similars to 1242 :
# similars to 1243 :
# similars to 1244 :
# similars to 1245 :
# similars to 1246 :
# similars to 1247 :
# similars to 1248 :
# similars to 1249 :
# similars to 1250 :
# similars to 1251 :
# similars to 1252 :
# similars to 1253 :
# similars to 1254 :
# similars to 1255 :
# similars to 1256 :
# similars to 1257 :
# similars to 1258 :
# similars to 1259 :
# similars to 1260 : 1269,
# similars to 1261 :
# similars to 1262 :
# similars to 1263 :
# similars to 1264 :
# similars to 1265 :
# similars to 1266 :
# similars to 1267 :
# similars to 1268 :
# similars to 1269 :
# similars to 1270 :
# similars to 1271 :
# similars to 1272 :
# similars to 1273 :
# similars to 1274 :
# similars to 1275 :
# similars to 1276 :
# similars to 1277 :
# similars to 1278 :
# similars to 1279 :
# similars to 1280 :
# similars to 1281 :
# similars to 1282 :
# similars to 1283 :
# similars to 1284 :
# similars to 1285 :
# similars to 1286 :
# similars to 1287 :
# similars to 1288 :
# similars to 1289 :
# similars to 1290 :
# similars to 1291 :
# similars to 1292 :
# similars to 1293 :
# similars to 1294 :
# similars to 1295 :
# similars to 1296 :
# similars to 1297 :
# similars to 1298 :
# similars to 1299 :
# similars to 1300 :
# similars to 1301 :
# similars to 1302 :
# similars to 1303 :
# similars to 1304 :
# similars to 1305 :
# similars to 1306 :
# similars to 1307 :
# similars to 1308 :
# similars to 1309 :
# similars to 1310 :
# similars to 1311 :
# similars to 1312 :
# similars to 1313 :
# similars to 1314 :
# similars to 1315 :
# similars to 1316 :
# similars to 1317 :
# similars to 1318 :
# similars to 1319 :
# similars to 1320 :
# similars to 1321 :
# similars to 1322 :
# similars to 1323 :
# similars to 1324 :
# similars to 1325 :
# similars to 1326 :
# similars to 1327 :
# similars to 1328 :
# similars to 1329 :
# similars to 1330 :
# similars to 1331 :
# similars to 1332 :
# similars to 1333 :
# similars to 1334 :
# similars to 1335 :
# similars to 1336 :
# similars to 1337 :
# similars to 1338 :
# similars to 1339 :
# similars to 1340 :
# similars to 1341 :
# similars to 1342 :
# similars to 1343 :
# similars to 1344 :
# similars to 1345 :
# similars to 1346 : 1387,1452,1671,1802,1828,1876,1995,
# similars to 1347 :
# similars to 1348 :
# similars to 1349 :
# similars to 1350 :
# similars to 1351 :
# similars to 1352 :
# similars to 1353 :
# similars to 1354 :
# similars to 1355 : 1410,
# similars to 1356 :
# similars to 1357 :
# similars to 1358 :
# similars to 1359 :
# similars to 1360 :
# similars to 1361 :
# similars to 1362 :
# similars to 1363 :
# similars to 1364 :
# similars to 1365 :
# similars to 1366 :
# similars to 1367 :
# similars to 1368 : 1387,1452,1671,1995,
# similars to 1369 :
# similars to 1370 :
# similars to 1371 :
# similars to 1372 :
# similars to 1373 :
# similars to 1374 :
# similars to 1375 :
# similars to 1376 :
# similars to 1377 :
# similars to 1378 :
# similars to 1379 :
# similars to 1380 :
# similars to 1381 :
# similars to 1382 :
# similars to 1383 :
# similars to 1384 :
# similars to 1385 :
# similars to 1386 :
# similars to 1387 : 1449,1452,1475,1633,1671,1732,1802,1828,1876,1995,
# similars to 1388 :
# similars to 1389 :
# similars to 1390 :
# similars to 1391 :
# similars to 1392 :
# similars to 1393 :
# similars to 1394 :
# similars to 1395 :
# similars to 1396 :
# similars to 1397 :
# similars to 1398 :
# similars to 1399 :
# similars to 1400 :
# similars to 1401 :
# similars to 1402 :
# similars to 1403 :
# similars to 1404 :
# similars to 1405 :
# similars to 1406 :
# similars to 1407 :
# similars to 1408 :
# similars to 1409 :
# similars to 1410 :
# similars to 1411 :
# similars to 1412 :
# similars to 1413 :
# similars to 1414 :
# similars to 1415 :
# similars to 1416 :
# similars to 1417 :
# similars to 1418 :
# similars to 1419 :
# similars to 1420 :
# similars to 1421 :
# similars to 1422 :
# similars to 1423 :
# similars to 1424 :
# similars to 1425 :
# similars to 1426 :
# similars to 1427 :
# similars to 1428 :
# similars to 1429 :
# similars to 1430 :
# similars to 1431 :
# similars to 1432 :
# similars to 1433 :
# similars to 1434 :
# similars to 1435 :
# similars to 1436 :
# similars to 1437 :
# similars to 1438 :
# similars to 1439 :
# similars to 1440 :
# similars to 1441 :
# similars to 1442 :
# similars to 1443 :
# similars to 1444 : 1492,
# similars to 1445 :
# similars to 1446 :
# similars to 1447 :
# similars to 1448 :
# similars to 1449 : 1452,1828,1876,
# similars to 1450 :
# similars to 1451 :
# similars to 1452 : 1475,1633,1671,1802,1828,1876,1995,
# similars to 1453 :
# similars to 1454 :
# similars to 1455 :
# similars to 1456 :
# similars to 1457 :
# similars to 1458 :
# similars to 1459 :
# similars to 1460 :
# similars to 1461 :
# similars to 1462 :
# similars to 1463 :
# similars to 1464 :
# similars to 1465 :
# similars to 1466 :
# similars to 1467 : 1633,1643,1995,
# similars to 1468 :
# similars to 1469 :
# similars to 1470 :
# similars to 1471 :
# similars to 1472 :
# similars to 1473 :
# similars to 1474 :
# similars to 1475 : 1633,1671,1709,1802,1828,1995,
# similars to 1476 :
# similars to 1477 :
# similars to 1478 :
# similars to 1479 :
# similars to 1480 :
# similars to 1481 :
# similars to 1482 :
# similars to 1483 :
# similars to 1484 :
# similars to 1485 :
# similars to 1486 :
# similars to 1487 :
# similars to 1488 :
# similars to 1489 :
# similars to 1490 :
# similars to 1491 :
# similars to 1492 :
# similars to 1493 :
# similars to 1494 :
# similars to 1495 :
# similars to 1496 :
# similars to 1497 :
# similars to 1498 :
# similars to 1499 :
# similars to 1500 :
# similars to 1501 :
# similars to 1502 :
# similars to 1503 :
# similars to 1504 :
# similars to 1505 :
# similars to 1506 :
# similars to 1507 :
# similars to 1508 :
# similars to 1509 :
# similars to 1510 :
# similars to 1511 :
# similars to 1512 :
# similars to 1513 :
# similars to 1514 :
# similars to 1515 :
# similars to 1516 :
# similars to 1517 :
# similars to 1518 :
# similars to 1519 :
# similars to 1520 :
# similars to 1521 :
# similars to 1522 :
# similars to 1523 :
# similars to 1524 :
# similars to 1525 :
# similars to 1526 :
# similars to 1527 :
# similars to 1528 :
# similars to 1529 :
# similars to 1530 :
# similars to 1531 :
# similars to 1532 :
# similars to 1533 :
# similars to 1534 :
# similars to 1535 :
# similars to 1536 :
# similars to 1537 :
# similars to 1538 :
# similars to 1539 :
# similars to 1540 :
# similars to 1541 :
# similars to 1542 :
# similars to 1543 :
# similars to 1544 :
# similars to 1545 :
# similars to 1546 :
# similars to 1547 :
# similars to 1548 :
# similars to 1549 :
# similars to 1550 :
# similars to 1551 :
# similars to 1552 :
# similars to 1553 :
# similars to 1554 :
# similars to 1555 :
# similars to 1556 :
# similars to 1557 :
# similars to 1558 : 1796,
# similars to 1559 :
# similars to 1560 :
# similars to 1561 :
# similars to 1562 :
# similars to 1563 :
# similars to 1564 :
# similars to 1565 :
# similars to 1566 :
# similars to 1567 :
# similars to 1568 : 1861,
# similars to 1569 :
# similars to 1570 :
# similars to 1571 :
# similars to 1572 :
# similars to 1573 :
# similars to 1574 :
# similars to 1575 :
# similars to 1576 :
# similars to 1577 :
# similars to 1578 :
# similars to 1579 :
# similars to 1580 :
# similars to 1581 :
# similars to 1582 :
# similars to 1583 :
# similars to 1584 :
# similars to 1585 :
# similars to 1586 :
# similars to 1587 :
# similars to 1588 :
# similars to 1589 :
# similars to 1590 :
# similars to 1591 :
# similars to 1592 :
# similars to 1593 :
# similars to 1594 :
# similars to 1595 :
# similars to 1596 :
# similars to 1597 :
# similars to 1598 :
# similars to 1599 :
# similars to 1600 :
# similars to 1601 :
# similars to 1602 :
# similars to 1603 :
# similars to 1604 :
# similars to 1605 :
# similars to 1606 :
# similars to 1607 :
# similars to 1608 :
# similars to 1609 :
# similars to 1610 :
# similars to 1611 :
# similars to 1612 :
# similars to 1613 :
# similars to 1614 :
# similars to 1615 :
# similars to 1616 :
# similars to 1617 :
# similars to 1618 :
# similars to 1619 :
# similars to 1620 :
# similars to 1621 :
# similars to 1622 :
# similars to 1623 :
# similars to 1624 :
# similars to 1625 :
# similars to 1626 :
# similars to 1627 :
# similars to 1628 :
# similars to 1629 :
# similars to 1630 :
# similars to 1631 :
# similars to 1632 :
# similars to 1633 : 1828,1995,
# similars to 1634 :
# similars to 1635 :
# similars to 1636 :
# similars to 1637 :
# similars to 1638 :
# similars to 1639 :
# similars to 1640 :
# similars to 1641 :
# similars to 1642 :
# similars to 1643 :
# similars to 1644 :
# similars to 1645 :
# similars to 1646 :
# similars to 1647 :
# similars to 1648 :
# similars to 1649 :
# similars to 1650 :
# similars to 1651 :
# similars to 1652 :
# similars to 1653 :
# similars to 1654 :
# similars to 1655 :
# similars to 1656 :
# similars to 1657 :
# similars to 1658 :
# similars to 1659 :
# similars to 1660 :
# similars to 1661 :
# similars to 1662 :
# similars to 1663 :
# similars to 1664 :
# similars to 1665 :
# similars to 1666 :
# similars to 1667 :
# similars to 1668 :
# similars to 1669 :
# similars to 1670 :
# similars to 1671 : 1732,1802,1828,1995,
# similars to 1672 :
# similars to 1673 :
# similars to 1674 :
# similars to 1675 :
# similars to 1676 :
# similars to 1677 :
# similars to 1678 :
# similars to 1679 :
# similars to 1680 :
# similars to 1681 :
# similars to 1682 :
# similars to 1683 :
# similars to 1684 :
# similars to 1685 :
# similars to 1686 :
# similars to 1687 :
# similars to 1688 :
# similars to 1689 :
# similars to 1690 :
# similars to 1691 :
# similars to 1692 :
# similars to 1693 :
# similars to 1694 :
# similars to 1695 :
# similars to 1696 :
# similars to 1697 :
# similars to 1698 : 1718,
# similars to 1699 :
# similars to 1700 :
# similars to 1701 :
# similars to 1702 :
# similars to 1703 :
# similars to 1704 :
# similars to 1705 :
# similars to 1706 :
# similars to 1707 :
# similars to 1708 :
# similars to 1709 :
# similars to 1710 :
# similars to 1711 :
# similars to 1712 :
# similars to 1713 :
# similars to 1714 :
# similars to 1715 :
# similars to 1716 :
# similars to 1717 :
# similars to 1718 :
# similars to 1719 : 1888,1974,
# similars to 1720 :
# similars to 1721 :
# similars to 1722 :
# similars to 1723 :
# similars to 1724 :
# similars to 1725 : 1989,
# similars to 1726 :
# similars to 1727 : 1952,
# similars to 1728 :
# similars to 1729 :
# similars to 1730 :
# similars to 1731 :
# similars to 1732 : 1828,
# similars to 1733 :
# similars to 1734 :
# similars to 1735 :
# similars to 1736 :
# similars to 1737 :
# similars to 1738 :
# similars to 1739 :
# similars to 1740 :
# similars to 1741 :
# similars to 1742 :
# similars to 1743 :
# similars to 1744 :
# similars to 1745 :
# similars to 1746 :
# similars to 1747 :
# similars to 1748 :
# similars to 1749 :
# similars to 1750 :
# similars to 1751 :
# similars to 1752 :
# similars to 1753 :
# similars to 1754 :
# similars to 1755 :
# similars to 1756 :
# similars to 1757 :
# similars to 1758 :
# similars to 1759 :
# similars to 1760 :
# similars to 1761 :
# similars to 1762 :
# similars to 1763 :
# similars to 1764 :
# similars to 1765 :
# similars to 1766 :
# similars to 1767 :
# similars to 1768 :
# similars to 1769 :
# similars to 1770 :
# similars to 1771 :
# similars to 1772 :
# similars to 1773 :
# similars to 1774 :
# similars to 1775 :
# similars to 1776 :
# similars to 1777 :
# similars to 1778 :
# similars to 1779 :
# similars to 1780 :
# similars to 1781 :
# similars to 1782 :
# similars to 1783 :
# similars to 1784 :
# similars to 1785 :
# similars to 1786 :
# similars to 1787 :
# similars to 1788 :
# similars to 1789 :
# similars to 1790 :
# similars to 1791 :
# similars to 1792 :
# similars to 1793 :
# similars to 1794 :
# similars to 1795 : 1845,
# similars to 1796 :
# similars to 1797 :
# similars to 1798 :
# similars to 1799 :
# similars to 1800 :
# similars to 1801 :
# similars to 1802 : 1828,1868,1876,1995,
# similars to 1803 :
# similars to 1804 :
# similars to 1805 :
# similars to 1806 :
# similars to 1807 :
# similars to 1808 :
# similars to 1809 :
# similars to 1810 :
# similars to 1811 :
# similars to 1812 :
# similars to 1813 :
# similars to 1814 :
# similars to 1815 :
# similars to 1816 :
# similars to 1817 :
# similars to 1818 :
# similars to 1819 :
# similars to 1820 :
# similars to 1821 :
# similars to 1822 :
# similars to 1823 :
# similars to 1824 :
# similars to 1825 :
# similars to 1826 :
# similars to 1827 :
# similars to 1828 : 1876,1995,
# similars to 1829 :
# similars to 1830 :
# similars to 1831 :
# similars to 1832 :
# similars to 1833 :
# similars to 1834 :
# similars to 1835 :
# similars to 1836 :
# similars to 1837 :
# similars to 1838 :
# similars to 1839 :
# similars to 1840 :
# similars to 1841 :
# similars to 1842 :
# similars to 1843 :
# similars to 1844 :
# similars to 1845 :
# similars to 1846 :
# similars to 1847 :
# similars to 1848 :
# similars to 1849 :
# similars to 1850 :
# similars to 1851 :
# similars to 1852 :
# similars to 1853 :
# similars to 1854 :
# similars to 1855 :
# similars to 1856 :
# similars to 1857 :
# similars to 1858 :
# similars to 1859 :
# similars to 1860 :
# similars to 1861 :
# similars to 1862 :
# similars to 1863 :
# similars to 1864 :
# similars to 1865 :
# similars to 1866 :
# similars to 1867 :
# similars to 1868 :
# similars to 1869 :
# similars to 1870 :
# similars to 1871 :
# similars to 1872 :
# similars to 1873 :
# similars to 1874 :
# similars to 1875 :
# similars to 1876 :
# similars to 1877 :
# similars to 1878 :
# similars to 1879 :
# similars to 1880 :
# similars to 1881 :
# similars to 1882 :
# similars to 1883 :
# similars to 1884 :
# similars to 1885 :
# similars to 1886 :
# similars to 1887 :
# similars to 1888 : 1974,
# similars to 1889 :
# similars to 1890 :
# similars to 1891 :
# similars to 1892 :
# similars to 1893 :
# similars to 1894 :
# similars to 1895 :
# similars to 1896 :
# similars to 1897 :
# similars to 1898 :
# similars to 1899 :
# similars to 1900 :
# similars to 1901 :
# similars to 1902 :
# similars to 1903 :
# similars to 1904 :
# similars to 1905 :
# similars to 1906 :
# similars to 1907 :
# similars to 1908 :
# similars to 1909 :
# similars to 1910 :
# similars to 1911 :
# similars to 1912 :
# similars to 1913 :
# similars to 1914 :
# similars to 1915 :
# similars to 1916 :
# similars to 1917 :
# similars to 1918 :
# similars to 1919 :
# similars to 1920 :
# similars to 1921 :
# similars to 1922 : 1989,
# similars to 1923 :
# similars to 1924 :
# similars to 1925 :
# similars to 1926 :
# similars to 1927 :
# similars to 1928 :
# similars to 1929 :
# similars to 1930 :
# similars to 1931 :
# similars to 1932 :
# similars to 1933 :
# similars to 1934 :
# similars to 1935 :
# similars to 1936 :
# similars to 1937 :
# similars to 1938 :
# similars to 1939 :
# similars to 1940 :
# similars to 1941 :
# similars to 1942 :
# similars to 1943 :
# similars to 1944 :
# similars to 1945 :
# similars to 1946 :
# similars to 1947 :
# similars to 1948 :
# similars to 1949 :
# similars to 1950 :
# similars to 1951 :
# similars to 1952 :
# similars to 1953 :
# similars to 1954 :
# similars to 1955 :
# similars to 1956 :
# similars to 1957 :
# similars to 1958 :
# similars to 1959 :
# similars to 1960 :
# similars to 1961 :
# similars to 1962 :
# similars to 1963 :
# similars to 1964 :
# similars to 1965 :
# similars to 1966 :
# similars to 1967 :
# similars to 1968 :
# similars to 1969 :
# similars to 1970 :
# similars to 1971 :
# similars to 1972 :
# similars to 1973 :
# similars to 1974 :
# similars to 1975 :
# similars to 1976 :
# similars to 1977 :
# similars to 1978 :
# similars to 1979 :
# similars to 1980 :
# similars to 1981 :
# similars to 1982 :
# similars to 1983 :
# similars to 1984 :
# similars to 1985 :
# similars to 1986 :
# similars to 1987 :
# similars to 1988 :
# similars to 1989 :
# similars to 1990 :
# similars to 1991 :
# similars to 1992 :
# similars to 1993 :
# similars to 1994 :
# similars to 1995 :
# similars to 1996 :
# similars to 1997 :
# similars to 1998 :
# similars to 1999 :
