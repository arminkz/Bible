# %%
import pandas as pd 

data = pd.read_csv("Dataset2.csv") 

# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#   poisonous cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0         p         x           s         n       t    p               f
# 1         e         b           s         w       t    l               f
# 2         p         x           y         w       t    p               f
# 3         e         x           s         g       f    n               f
# 4         e         x           y         y       t    a               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          n   ...                          s
# 2            c         n          n   ...                          s
# 3            w         b          k   ...                          s
# 4            c         b          n   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       m
# 2           o         p                 k          s       u
# 3           o         e                 n          a       g
# 4           o         p                 k          n       g
#
# [5 rows x 23 columns]

# %%
y = data['poisonous'].values #classification label
X = data.drop('poisonous',axis=1).values

# %%
#convert categorical/ordinal into one-hot
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder()
enc.fit(X)
X_oh = enc.transform(X).toarray()

# %%
#use dicision tree to classify 
from sklearn import tree
#from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_oh, y, test_size=0.2, random_state=0)

clf = tree.DecisionTreeClassifier(random_state=0)
clf = clf.fit(X_train , y_train)
acc = clf.score(X_test , y_test)
print("Decision Tree Accuracy : ",acc)
# Out:
# Decision Tree Accuracy :  1.0

# %%
#plot graph
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
d = graph.render("dt2_plot")
print("Plot saved in :",d)
# Out:
# Plot saved in : dt2_plot.pdf

# %%
#use random forest to classify 
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(X_oh, y, test_size=0.2, random_state=0)

clf = RandomForestClassifier(n_estimators=100,random_state=0)
clf = clf.fit(X_train , y_train)
acc = clf.score(X_test , y_test)
print("Random Forest Accuracy : ",acc)
# Out:
# Random Forest Accuracy :  1.0
